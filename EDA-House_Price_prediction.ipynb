# %% [markdown]
# ### Project Name: House Prices: Advanced Regression Techniques
# The main aim of this project is to predict the house price based on various features which we will discuss as we go ahead
#
# Dataset to downloaded from the below link<br>
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# ##### All the Lifecycle In A Data Science Projects
# - Data Analysis
# - Feature Engineering
# - Feature Selection
# - Model Building
# - Model Deployment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('train_AHPP.csv') 
pd.set_option('display.max_columns',None)

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset.shape
# Out:
# (1460, 81)

# %% [markdown]
# ##### In Data Analysis We will Analyze To Find out the below stuff
# - Missing Values
# - All The Numerical Variables
# - Distribution of the Numerical Variables
# - Categorical Variables
# - Cardinality of Categorical Variables
# - Outliers
# - Relationship between independent and dependent feature(SalePrice)

# %% [markdown]
# ### Missing values

# %%
## Finding the features which has null values
features_with_null = [feature for feature in dataset.columns if dataset[feature].isnull().sum()>0]
for feature in features_with_null:
    print(feature ," = ", np.round(dataset[feature].isnull().mean(),4) ,' % missing values')
# Out:
# LotFrontage  =  0.1774  % missing values
# Alley  =  0.9377  % missing values
# MasVnrType  =  0.0055  % missing values
# MasVnrArea  =  0.0055  % missing values
# BsmtQual  =  0.0253  % missing values
# BsmtCond  =  0.0253  % missing values
# BsmtExposure  =  0.026  % missing values
# BsmtFinType1  =  0.0253  % missing values
# BsmtFinType2  =  0.026  % missing values
# Electrical  =  0.0007  % missing values
# FireplaceQu  =  0.4726  % missing values
# GarageType  =  0.0555  % missing values
# GarageYrBlt  =  0.0555  % missing values
# GarageFinish  =  0.0555  % missing values
# GarageQual  =  0.0555  % missing values
# GarageCond  =  0.0555  % missing values
# PoolQC  =  0.9952  % missing values
# Fence  =  0.8075  % missing values
# MiscFeature  =  0.963  % missing values

# %%
# now we will check if there is any relation between missing values ans the saleprice

for feature in features_with_null:
    data = dataset.copy()
    
    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    data[feature] = np.where(data[feature].isnull(),1,0)
    
    data.groupby(feature)['SalePrice'].median().plot(kind='bar',color=['blue','orange'])
    plt.title(feature)
    plt.show()

# %% [markdown]
# Here With the relation between the missing values and the dependent variable is clearly visible.So We need to replace these nan values with something meaningful which we will do in the Feature Engineering section

# %%
#From the above dataset some of the features like Id is not required,we can drop this column in feature engineering
dataset.index.size
# Out:
# 1460

# %% [markdown]
# ### Numerical Variables

# %%
numerical_feature = [feature for feature in dataset.columns if dataset[feature].dtype !='O']

# %%
len(numerical_feature)
# Out:
# 38

# %%
dataset[numerical_feature].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# #### Temporal Variable(eg DateaTime variable)

# %%
#all the features with year
year_feature = [feature for feature in numerical_feature if 'Year' in feature or 'Yr' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.show()

# %%
## Here we will compare the difference between All years feature with SalePrice

for feature in year_feature:
    if feature != 'YrSold':
        data=dataset.copy()
        ## We will capture the difference between year variable and year the house was sold for
        data[feature]=data['YrSold']-data[feature]

        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# ### Numerical variable
# 1. Discrete
# 2. Continuous

# %%
Discrete_feature = [feature for feature in numerical_feature if len(dataset[feature].unique())<25 and feature not in year_feature+['Id']]
Discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[Discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
for feature in Discrete_feature:
    data=dataset.copy()
    
    data.groupby(feature)['SalePrice'].median().plot.bar(color=list('rgby'))
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %%
Continuous_feature = [feature  for feature in numerical_feature if feature not in Discrete_feature+['Id']+year_feature]
Continuous_feature
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in Continuous_feature:
    data=dataset.copy()
    
    plt.hist(data[feature],bins=25)
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# %%
## Log transformation
for feature in Continuous_feature:
    data=dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.title(feature)
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# ### outliers

# %%
for feature in Continuous_feature:
    data=dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### Categorical variable

# %%
categorical_feature=[feature for feature in dataset.columns if dataset[feature].dtype =='O']
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
dataset[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_feature:
    print(feature,"count : ",len(dataset[feature].unique()) )
# Out:
# MSZoning count :  5
# Street count :  2
# Alley count :  3
# LotShape count :  4
# LandContour count :  4
# Utilities count :  2
# LotConfig count :  5
# LandSlope count :  3
# Neighborhood count :  25
# Condition1 count :  9
# Condition2 count :  8
# BldgType count :  5
# HouseStyle count :  8
# RoofStyle count :  6
# RoofMatl count :  8
# Exterior1st count :  15
# Exterior2nd count :  16
# MasVnrType count :  5
# ExterQual count :  4
# ExterCond count :  5
# Foundation count :  6
# BsmtQual count :  5
# BsmtCond count :  5
# BsmtExposure count :  5
# BsmtFinType1 count :  7
# BsmtFinType2 count :  7
# Heating count :  6
# HeatingQC count :  5
# CentralAir count :  2
# Electrical count :  6
# KitchenQual count :  4
# Functional count :  7
# FireplaceQu count :  6
# GarageType count :  7
# GarageFinish count :  4
# GarageQual count :  6
# GarageCond count :  6
# PavedDrive count :  3
# PoolQC count :  4
# Fence count :  5
# MiscFeature count :  5
# SaleType count :  9
# ...

# %%
for feature in categorical_feature:
    data=dataset.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()
